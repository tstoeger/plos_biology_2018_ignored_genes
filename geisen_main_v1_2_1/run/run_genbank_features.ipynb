# %% [markdown]
# # Purpose: RNA properties

# %% [markdown]
# # Initialization

# %%
# %matplotlib inline 
# %reload_ext autoreload
# %autoreload 2

# %%
src_dir = './../src/'
import sys
sys.path[0] = src_dir

# %%
from geisen import prepare
from geisen import settings
# Out:
# Using temporary switch for setting project paths.Needs replacement before deploying

# %% [markdown]
# # Tier 1

# %% [markdown]
# ## RNA from genomic

# %%
s = settings.retreive_genome_download_settings()

# %%
taxa = list(s.keys())

# %%
for taxon in taxa:
    prepare.genbank_cds_rna_features(taxon_id=taxon)
# Out:
# Initiating download of experimental RNA sequences
# Initialize download of genome of taxon 9606
# Start download of cds_from_genomic of taxon 9606
# Succesfully downloaded ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.36_GRCh38.p10/GCF_000001405.36_GRCh38.p10_cds_from_genomic.fna.gz to /Users/tstoeger/Projects/geisen_main/data/internal/genomes/cds_from_genomic/GCF_000001405.36_GRCh38.p10_cds_from_genomic.fna.gz
# Decompress predicted CDS RNA Sequence
# Start to extract properties of the RNA
# Exporting genbank features of CDS from genomic to /Users/tstoeger/Projects/geisen_main/data/out/genbank/genomic_cds/genbank_genomic_cds_9606.csv .
# Initiating download of experimental RNA sequences
# Initialize download of genome of taxon 10090
# Start download of cds_from_genomic of taxon 10090
# ...

# %%
for taxon in taxa:
    prepare.genbank_genomic_rna_features(taxon_id=taxon)
# Out:
# Initiating download of predicted genomic RNA sequences
# Initialize download of genome of taxon 9606
# Start download of rna_from_genomic of taxon 9606
# Succesfully downloaded ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.36_GRCh38.p10/GCF_000001405.36_GRCh38.p10_rna_from_genomic.fna.gz to /Users/tstoeger/Projects/geisen_main/data/internal/genomes/rna_from_genomic/GCF_000001405.36_GRCh38.p10_rna_from_genomic.fna.gz
# Decompress genomic RNA Sequence
# Start to extract properties of the RNA
# Exporting genbank features of genomic RNA to /Users/tstoeger/Projects/geisen_main/data/out/genbank/genomic_rna/genbank_genomic_rna_9606.csv .
# Initiating download of predicted genomic RNA sequences
# Initialize download of genome of taxon 10090
# Start download of rna_from_genomic of taxon 10090
# ...

# %%
for taxon in taxa:
    prepare.genbank_validated_rna_features(taxon_id=taxon)
# Out:
# Initiating download of experimental RNA sequences
# Initialize download of genome of taxon 9606
# Start download of rna of taxon 9606
# Succesfully downloaded ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.36_GRCh38.p10/GCF_000001405.36_GRCh38.p10_rna.gbff.gz to /Users/tstoeger/Projects/geisen_main/data/internal/genomes/rna/GCF_000001405.36_GRCh38.p10_rna.gbff.gz
# Decompress RNA Sequence
# Start to extract properties of the RNA
# Exporing genbank features of verified RNA to /Users/tstoeger/Projects/geisen_main/data/out/genbank/validated_rna/genbank_validated_rna_9606.csv .
# Initiating download of experimental RNA sequences
# Initialize download of genome of taxon 10090
# Start download of rna of taxon 10090
# Succesfully downloaded ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/635/GCF_000001635.25_GRCm38.p5/GCF_000001635.25_GRCm38.p5_rna.gbff.gz to /Users/tstoeger/Projects/geisen_main/data/internal/genomes/rna/GCF_000001635.25_GRCm38.p5_rna.gbff.gz
# ...

# %%
for taxon in taxa:
    prepare.genbank_gene_features(taxon_id=taxon)
# Out:
# Using machine-encoded switch for setting project paths.Needs replacement upon deploying / sharing with others.
# Initiating download of genomic sequence
# Initialize download of genome of taxon 9606
# Start download of genomic of taxon 9606
# Succesfully downloaded ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.36_GRCh38.p10/GCF_000001405.36_GRCh38.p10_genomic.gbff.gz to /Users/tstoeger/Projects/geisen_main/data/internal/genomes/genomic/GCF_000001405.36_GRCh38.p10_genomic.gbff.gz
# Initiating isolation of standard replicons
# Exporing genbank features to /Users/tstoeger/Projects/geisen_main/data/out/genbank/genbank_gene/genbank_gene_9606.csv .
# Initiating download of genomic sequence
# Initialize download of genome of taxon 10090
# Start download of genomic of taxon 10090
# ...
