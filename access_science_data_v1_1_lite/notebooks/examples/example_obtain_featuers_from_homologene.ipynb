# %%
from access_biology_data import properties
from access_biology_data import relations

# %%
df_fly = properties.seg_swissprot(taxon_id=7227)
df_human = relations.relate_to_homologene(taxon_id=9606, df_orig=df_fly)

# %%
df_human.head()
# Out:
#    gene_ncbi  SEG_swissprot: Total (via taxon 7227)  \
# 0         16                                   12.0
# 1         34                                    0.0
# 2         51                                   41.0
# 3         52                                    0.0
# 4         60                                    0.0
#
#    SEG_swissprot: Fraction_of_protein (via taxon 7227)  \
# 0                                           0.012422
# 1                                           0.000000
# 2                                           0.061286
# 3                                           0.000000
# 4                                           0.000000
#
#    SEG_swissprot: Longest (via taxon 7227)  \
# 0                                     12.0
# 1                                      0.0
# 2                                     16.0
# 3                                      0.0
# 4                                      0.0
#
# ...
