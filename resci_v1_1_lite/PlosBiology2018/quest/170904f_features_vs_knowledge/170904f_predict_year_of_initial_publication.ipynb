# %%
# %matplotlib inline  
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys

import numpy as np
import pandas as pd

from access_science_shared import standardizer
from access_literature_data import medline

sys.path.append('./../../src')

import resci_inout as inout
import nar170902_discovery_year as nar_discovery
import nar170823f_prediction_datasets as pred
import nar170830f_predictions as pred_manager

# %% [markdown]
# # Shared settings

# %%
project_base = '170904f_predict_year_of_initial_publication'
date_stamp = '170904'

# %%
taxon_id = 9606
ref_genes = standardizer.reference_genes(taxon_id, 'orp')
df_targets = nar_discovery.get_year_of_discovery(taxon_id, ref_genes)


def maker(sub_name, u_features, df_target):
    pred_manager.make_base(
        project_base = project_base,
        sub_name = sub_name,
        ref_genes = ref_genes,
        u_features = u_features,
        df_target = df_target)

# %% [markdown]
# # Specific datasets

# %%
for feature_to_predict in ['first_year', 'first_solo_year']:
        
#### September 4th 
    
#     sub_name = '{}_human_Bio_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_biophysics(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    

    
#     sub_name = '{}_human_Rel_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_related_genes(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    
    
    
#     sub_name = '{}_human_Exp_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_human_experiments(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    
    
#     sub_name = '{}_human_BioExp_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_biophysics(ref_genes, taxon_id),
#          **pred.retreive_human_experiments(ref_genes, taxon_id)
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    
    
    
#     sub_name = '{}_human_BioExpRel_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_biophysics(ref_genes, taxon_id),
#          **pred.retreive_human_experiments(ref_genes, taxon_id),
#          **pred.retreive_related_genes(ref_genes, taxon_id)
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    


    
#     sub_name = '{}_human_Yea_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_homologene_discoveries(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    

    
#     sub_name = '{}_human_BioYea_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_biophysics(ref_genes, taxon_id),
#          **pred.retreive_homologene_discoveries(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    

#     sub_name = '{}_human_RelYea_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_related_genes(ref_genes, taxon_id),
#          **pred.retreive_homologene_discoveries(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    

#     sub_name = '{}_human_ExpYea_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_human_experiments(ref_genes, taxon_id),
#          **pred.retreive_homologene_discoveries(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    

#     sub_name = '{}_human_BioExpYea_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_biophysics(ref_genes, taxon_id),
#          **pred.retreive_human_experiments(ref_genes, taxon_id),
#          **pred.retreive_homologene_discoveries(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    

#     sub_name = '{}_human_BioExpRelYea_{}'.format(date_stamp, feature_to_predict)
#     u = {
#          **pred.retreive_biophysics(ref_genes, taxon_id),
#          **pred.retreive_human_experiments(ref_genes, taxon_id),
#          **pred.retreive_related_genes(ref_genes, taxon_id),
#          **pred.retreive_homologene_discoveries(ref_genes, taxon_id),
#     }
#     maker(
#         sub_name = sub_name,
#         u_features = u,
#         df_target = df_targets[[feature_to_predict]]
#     )
    

    
#### September 5th 

    
    sub_name = '{}_human_BioExpRelYeaYhe_{}'.format(date_stamp, feature_to_predict)
    u = {
         **pred.retreive_biophysics(ref_genes, taxon_id),
         **pred.retreive_human_experiments(ref_genes, taxon_id),
         **pred.retreive_related_genes(ref_genes, taxon_id),
         **pred.retreive_homologene_discoveries(ref_genes, taxon_id),
         **pred.retreive_homologene_description(ref_genes, taxon_id),
    }
    maker(
        sub_name = sub_name,
        u_features = u,
        df_target = df_targets[[feature_to_predict]]
    )
    
    sub_name = '{}_human_BioExpRelYhe_{}'.format(date_stamp, feature_to_predict)
    u = {
         **pred.retreive_biophysics(ref_genes, taxon_id),
         **pred.retreive_human_experiments(ref_genes, taxon_id),
         **pred.retreive_related_genes(ref_genes, taxon_id),
         **pred.retreive_homologene_description(ref_genes, taxon_id),
    }
    maker(
        sub_name = sub_name,
        u_features = u,
        df_target = df_targets[[feature_to_predict]]
    )
