# %%
# %matplotlib inline 
# %reload_ext autoreload
# %autoreload 2

src_dir = './../src/'
import sys
sys.path[0] = src_dir

from rbusa import prepare

# %% [markdown]
# # Tier 1

# %% [markdown]
# ## Web of Science DAIS

# %%
# %%time
prepare.wos_dais()
# Out:
# Processing batch  1 out of  320
# Processing batch  2 out of  320
# Processing batch  3 out of  320
# Processing batch  4 out of  320
# Processing batch  5 out of  320
# Processing batch  6 out of  320
# Processing batch  7 out of  320
# Processing batch  8 out of  320
# Processing batch  9 out of  320
# Processing batch  10 out of  320
# Processing batch  11 out of  320
# Processing batch  12 out of  320
# Processing batch  13 out of  320
# Processing batch  14 out of  320
# Processing batch  15 out of  320
# Processing batch  16 out of  320
# Processing batch  17 out of  320
# Processing batch  18 out of  320
# Processing batch  19 out of  320
# Processing batch  20 out of  320
# Processing batch  21 out of  320
# Processing batch  22 out of  320
# Processing batch  23 out of  320
# Processing batch  24 out of  320
# Processing batch  25 out of  320
# Processing batch  26 out of  320
# Processing batch  27 out of  320
# Processing batch  28 out of  320
# ...
